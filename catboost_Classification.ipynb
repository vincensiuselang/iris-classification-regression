# %%
# load dataset Iris

from sklearn.datasets import load_iris
import pandas as pd

dataset = load_iris()

df = pd.DataFrame(data=dataset.data, columns=dataset.feature_names)
df['target'] = dataset.target

# %%
# EDA

print(f'Cek missing values \n{df.isnull().sum()}', '\n')
print(f'\nTotal Missing values: \n{df.isnull().sum().sum()}')
# Out:
# Cek missing values
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# target               0
# dtype: int64
#
#
# Total Missing values:
# 0

# %%
# cek Outlier
import seaborn as sns 
import matplotlib.pyplot as plt

# Set up the matplotlib figure
plt.figure(figsize=(10, 8))

# Create a boxplot for each feature in the dataframe
for i, column in enumerate(df.columns, 1):
    plt.subplot(3, 2, i)
    sns.boxplot(y=df[column])
    plt.title(f'Boxplot of {column}')

plt.tight_layout()
plt.show()

# %%
# handle outlier

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Fungsi buat handle outlier pake metode IQR
def remove_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    
    # Batas bawah dan atas
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    # Filter data yang di dalam range
    df_clean = df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]
    
    return df_clean

# Handle outlier di 'sepal width (cm)'
df_outliers_removed = remove_outliers(df, 'sepal width (cm)')

# Plot boxplot setelah outlier dihapus
plt.figure(figsize=(6, 8))
sns.boxplot(y=df_outliers_removed['sepal width (cm)'])
plt.title('Boxplot of Sepal Width (cm) after Removing Outliers')
plt.show()

# %%
print(df_outliers_removed.columns)
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)', 'target'],
#       dtype='object')

# %%
# preprocessing

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import SelectKBest, f_classif
from imblearn.over_sampling import SMOTE

# preprocessing
# Split the data into features and target
X = df_outliers_removed.drop(columns=['target'])
y = df_outliers_removed['target']

smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.2, random_state=42)

# Select the top 2 features
selector = SelectKBest(score_func=f_classif, k=4)
X_train_selected = selector.fit_transform(X_train, y_train)
X_test_selected = selector.transform(X_test)

# Standardize the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_selected)
X_test_scaled = scaler.transform(X_test_selected)

# %%
# Training Model

from catboost import CatBoostClassifier
from sklearn.metrics import accuracy_score, classification_report

# modeling
# Initialize CatBoostClassifier
class_weights = {0: 1, 1: 1.5, 2: 1.2}  # Contoh aja, adjust sesuai proporsi data
model = CatBoostClassifier()

# Fit the model
model.fit(X_train_scaled, y_train, early_stopping_rounds=10)

# Predict on the test set
y_pred = model.predict(X_test_scaled)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
report = classification_report(y_test, y_pred)

print(f'Accuracy: {accuracy}')
print(f'Classification Report:\n{report}\n')

from sklearn.model_selection import cross_val_score
from catboost import CatBoostClassifier

model = CatBoostClassifier(verbose=0)  # Biar output training nggak rame
scores = cross_val_score(model, X_train_scaled, y_train, cv=5, scoring='accuracy')
print(f"Cross-validation accuracy: {scores.mean():.2f} ± {scores.std():.2f}")
# Out:
# Learning rate set to 0.071017
# 0:	learn: 1.0168144	total: 2.34ms	remaining: 2.34s
# 1:	learn: 0.9475314	total: 4.49ms	remaining: 2.24s
# 2:	learn: 0.8837646	total: 5.6ms	remaining: 1.86s
# 3:	learn: 0.8219458	total: 6.75ms	remaining: 1.68s
# 4:	learn: 0.7743717	total: 7.92ms	remaining: 1.58s
# 5:	learn: 0.7267478	total: 8.98ms	remaining: 1.49s
# 6:	learn: 0.6886268	total: 10.9ms	remaining: 1.54s
# 7:	learn: 0.6449673	total: 12ms	remaining: 1.49s
# 8:	learn: 0.6078578	total: 13.1ms	remaining: 1.44s
# 9:	learn: 0.5758394	total: 14.3ms	remaining: 1.41s
# 10:	learn: 0.5467206	total: 15.6ms	remaining: 1.4s
# 11:	learn: 0.5213915	total: 17.5ms	remaining: 1.44s
# 12:	learn: 0.4980261	total: 18.7ms	remaining: 1.42s
# 13:	learn: 0.4736122	total: 19.8ms	remaining: 1.39s
# 14:	learn: 0.4504179	total: 20.6ms	remaining: 1.35s
# 15:	learn: 0.4325925	total: 21.6ms	remaining: 1.33s
# 16:	learn: 0.4133168	total: 23.1ms	remaining: 1.34s
# 17:	learn: 0.3969634	total: 24.4ms	remaining: 1.33s
# 18:	learn: 0.3801202	total: 25.7ms	remaining: 1.33s
# 19:	learn: 0.3646155	total: 26.9ms	remaining: 1.32s
# 20:	learn: 0.3515536	total: 28.1ms	remaining: 1.31s
# 21:	learn: 0.3375488	total: 29.8ms	remaining: 1.32s
# 22:	learn: 0.3237926	total: 30.9ms	remaining: 1.31s
# 23:	learn: 0.3126564	total: 32.1ms	remaining: 1.3s
# 24:	learn: 0.3026602	total: 33.3ms	remaining: 1.3s
# 25:	learn: 0.2915550	total: 34.6ms	remaining: 1.29s
# 26:	learn: 0.2835199	total: 35.7ms	remaining: 1.29s
# 27:	learn: 0.2720433	total: 36.2ms	remaining: 1.26s
# 28:	learn: 0.2632205	total: 37.4ms	remaining: 1.25s
# 29:	learn: 0.2555611	total: 38.5ms	remaining: 1.25s
# 30:	learn: 0.2493846	total: 39.7ms	remaining: 1.24s
# 31:	learn: 0.2417353	total: 40.9ms	remaining: 1.24s
# 32:	learn: 0.2330279	total: 42.2ms	remaining: 1.24s
# 33:	learn: 0.2259773	total: 43.3ms	remaining: 1.23s
# 34:	learn: 0.2197986	total: 44.2ms	remaining: 1.22s
# 35:	learn: 0.2142994	total: 45.2ms	remaining: 1.21s
# 36:	learn: 0.2081074	total: 46.2ms	remaining: 1.2s
# 37:	learn: 0.2032486	total: 47.2ms	remaining: 1.19s
# 38:	learn: 0.1969957	total: 48.3ms	remaining: 1.19s
# 39:	learn: 0.1926245	total: 49.5ms	remaining: 1.19s
# 40:	learn: 0.1879376	total: 51.6ms	remaining: 1.21s
# 41:	learn: 0.1827453	total: 53ms	remaining: 1.21s
# 42:	learn: 0.1780893	total: 54.4ms	remaining: 1.21s
# 43:	learn: 0.1733400	total: 56.2ms	remaining: 1.22s
# 44:	learn: 0.1692005	total: 57.7ms	remaining: 1.22s
# 45:	learn: 0.1650699	total: 58.8ms	remaining: 1.22s
# 46:	learn: 0.1614184	total: 60.1ms	remaining: 1.22s
# 47:	learn: 0.1577259	total: 61.3ms	remaining: 1.21s
# 48:	learn: 0.1540141	total: 64.5ms	remaining: 1.25s
# 49:	learn: 0.1506053	total: 65.6ms	remaining: 1.25s
# 50:	learn: 0.1476048	total: 66.8ms	remaining: 1.24s
# 51:	learn: 0.1446471	total: 68.1ms	remaining: 1.24s
# 52:	learn: 0.1420677	total: 69.5ms	remaining: 1.24s
# 53:	learn: 0.1382252	total: 71.1ms	remaining: 1.25s
# 54:	learn: 0.1355886	total: 72.6ms	remaining: 1.25s
# 55:	learn: 0.1332743	total: 73.9ms	remaining: 1.25s
# 56:	learn: 0.1309051	total: 76.6ms	remaining: 1.27s
# 57:	learn: 0.1286958	total: 77.8ms	remaining: 1.26s
# 58:	learn: 0.1263131	total: 79.2ms	remaining: 1.26s
# 59:	learn: 0.1236695	total: 80.5ms	remaining: 1.26s
# 60:	learn: 0.1214407	total: 81.6ms	remaining: 1.26s
# 61:	learn: 0.1193849	total: 82.6ms	remaining: 1.25s
# 62:	learn: 0.1170572	total: 84.1ms	remaining: 1.25s
# 63:	learn: 0.1149249	total: 85.3ms	remaining: 1.25s
# 64:	learn: 0.1128337	total: 86.4ms	remaining: 1.24s
# 65:	learn: 0.1108845	total: 87.5ms	remaining: 1.24s
# 66:	learn: 0.1089702	total: 88.8ms	remaining: 1.24s
# 67:	learn: 0.1074746	total: 89.9ms	remaining: 1.23s
# 68:	learn: 0.1056387	total: 91ms	remaining: 1.23s
# 69:	learn: 0.1037389	total: 92ms	remaining: 1.22s
# 70:	learn: 0.1024223	total: 92.9ms	remaining: 1.22s
# 71:	learn: 0.1008189	total: 93.9ms	remaining: 1.21s
# 72:	learn: 0.0989823	total: 94.8ms	remaining: 1.2s
# 73:	learn: 0.0980409	total: 95.8ms	remaining: 1.2s
# 74:	learn: 0.0959680	total: 96.9ms	remaining: 1.19s
# 75:	learn: 0.0944044	total: 98ms	remaining: 1.19s
# 76:	learn: 0.0932984	total: 99.2ms	remaining: 1.19s
# 77:	learn: 0.0920124	total: 100ms	remaining: 1.19s
# 78:	learn: 0.0902149	total: 101ms	remaining: 1.18s
# 79:	learn: 0.0889176	total: 103ms	remaining: 1.18s
# 80:	learn: 0.0871385	total: 104ms	remaining: 1.17s
# 81:	learn: 0.0858226	total: 105ms	remaining: 1.17s
# 82:	learn: 0.0842971	total: 105ms	remaining: 1.16s
# 83:	learn: 0.0827029	total: 106ms	remaining: 1.16s
# 84:	learn: 0.0817386	total: 107ms	remaining: 1.16s
# 85:	learn: 0.0802476	total: 108ms	remaining: 1.15s
# 86:	learn: 0.0788499	total: 109ms	remaining: 1.15s
# 87:	learn: 0.0776553	total: 110ms	remaining: 1.14s
# 88:	learn: 0.0766056	total: 111ms	remaining: 1.14s
# 89:	learn: 0.0755660	total: 113ms	remaining: 1.14s
# 90:	learn: 0.0745512	total: 114ms	remaining: 1.14s
# 91:	learn: 0.0735693	total: 115ms	remaining: 1.13s
# 92:	learn: 0.0725558	total: 116ms	remaining: 1.13s
# 93:	learn: 0.0715268	total: 117ms	remaining: 1.13s
# 94:	learn: 0.0707342	total: 118ms	remaining: 1.13s
# 95:	learn: 0.0699843	total: 120ms	remaining: 1.13s
# 96:	learn: 0.0687708	total: 122ms	remaining: 1.13s
# 97:	learn: 0.0680122	total: 123ms	remaining: 1.13s
# 98:	learn: 0.0669778	total: 124ms	remaining: 1.13s
# 99:	learn: 0.0658272	total: 125ms	remaining: 1.12s
# 100:	learn: 0.0651380	total: 126ms	remaining: 1.12s
# 101:	learn: 0.0643770	total: 129ms	remaining: 1.14s
# 102:	learn: 0.0637947	total: 130ms	remaining: 1.14s
# 103:	learn: 0.0630199	total: 132ms	remaining: 1.14s
# 104:	learn: 0.0622383	total: 133ms	remaining: 1.13s
# 105:	learn: 0.0614044	total: 134ms	remaining: 1.13s
# 106:	learn: 0.0607936	total: 135ms	remaining: 1.13s
# 107:	learn: 0.0602340	total: 136ms	remaining: 1.12s
# 108:	learn: 0.0597042	total: 137ms	remaining: 1.12s
# 109:	learn: 0.0591439	total: 138ms	remaining: 1.12s
# 110:	learn: 0.0584082	total: 139ms	remaining: 1.11s
# 111:	learn: 0.0578401	total: 140ms	remaining: 1.11s
# 112:	learn: 0.0571939	total: 141ms	remaining: 1.11s
# 113:	learn: 0.0563947	total: 142ms	remaining: 1.1s
# 114:	learn: 0.0556516	total: 144ms	remaining: 1.1s
# 115:	learn: 0.0551696	total: 145ms	remaining: 1.1s
# 116:	learn: 0.0545709	total: 146ms	remaining: 1.1s
# 117:	learn: 0.0541597	total: 147ms	remaining: 1.1s
# 118:	learn: 0.0537464	total: 148ms	remaining: 1.09s
# 119:	learn: 0.0531526	total: 149ms	remaining: 1.09s
# 120:	learn: 0.0526067	total: 150ms	remaining: 1.09s
# 121:	learn: 0.0520348	total: 151ms	remaining: 1.08s
# 122:	learn: 0.0514705	total: 152ms	remaining: 1.08s
# 123:	learn: 0.0509958	total: 153ms	remaining: 1.08s
# 124:	learn: 0.0505795	total: 154ms	remaining: 1.07s
# 125:	learn: 0.0499349	total: 155ms	remaining: 1.07s
# 126:	learn: 0.0494126	total: 157ms	remaining: 1.08s
# 127:	learn: 0.0489194	total: 158ms	remaining: 1.07s
# 128:	learn: 0.0484096	total: 159ms	remaining: 1.07s
# 129:	learn: 0.0478897	total: 160ms	remaining: 1.07s
# 130:	learn: 0.0473547	total: 161ms	remaining: 1.07s
# 131:	learn: 0.0469832	total: 162ms	remaining: 1.06s
# 132:	learn: 0.0466083	total: 163ms	remaining: 1.06s
# 133:	learn: 0.0462375	total: 163ms	remaining: 1.05s
# 134:	learn: 0.0457740	total: 164ms	remaining: 1.05s
# 135:	learn: 0.0452368	total: 165ms	remaining: 1.05s
# 136:	learn: 0.0448526	total: 166ms	remaining: 1.04s
# 137:	learn: 0.0445185	total: 167ms	remaining: 1.04s
# 138:	learn: 0.0440860	total: 168ms	remaining: 1.04s
# 139:	learn: 0.0436893	total: 169ms	remaining: 1.04s
# 140:	learn: 0.0432381	total: 171ms	remaining: 1.04s
# 141:	learn: 0.0427536	total: 173ms	remaining: 1.04s
# 142:	learn: 0.0424124	total: 174ms	remaining: 1.04s
# 143:	learn: 0.0420965	total: 175ms	remaining: 1.04s
# 144:	learn: 0.0417514	total: 176ms	remaining: 1.04s
# 145:	learn: 0.0414323	total: 177ms	remaining: 1.04s
# 146:	learn: 0.0410005	total: 178ms	remaining: 1.03s
# 147:	learn: 0.0407126	total: 179ms	remaining: 1.03s
# 148:	learn: 0.0402817	total: 180ms	remaining: 1.03s
# 149:	learn: 0.0398653	total: 181ms	remaining: 1.03s
# 150:	learn: 0.0394939	total: 182ms	remaining: 1.03s
# 151:	learn: 0.0391914	total: 184ms	remaining: 1.03s
# 152:	learn: 0.0388704	total: 185ms	remaining: 1.02s
# 153:	learn: 0.0385554	total: 186ms	remaining: 1.02s
# 154:	learn: 0.0382441	total: 187ms	remaining: 1.02s
# 155:	learn: 0.0379867	total: 188ms	remaining: 1.02s
# 156:	learn: 0.0376711	total: 189ms	remaining: 1.02s
# 157:	learn: 0.0372896	total: 190ms	remaining: 1.01s
# 158:	learn: 0.0370207	total: 191ms	remaining: 1.01s
# 159:	learn: 0.0367772	total: 192ms	remaining: 1.01s
# 160:	learn: 0.0364563	total: 193ms	remaining: 1s
# 161:	learn: 0.0361016	total: 194ms	remaining: 1s
# 162:	learn: 0.0358539	total: 195ms	remaining: 999ms
# 163:	learn: 0.0355859	total: 196ms	remaining: 997ms
# 164:	learn: 0.0352574	total: 197ms	remaining: 997ms
# 165:	learn: 0.0350093	total: 198ms	remaining: 996ms
# 166:	learn: 0.0347376	total: 199ms	remaining: 994ms
# 167:	learn: 0.0345083	total: 200ms	remaining: 991ms
# 168:	learn: 0.0342644	total: 201ms	remaining: 989ms
# 169:	learn: 0.0340087	total: 202ms	remaining: 987ms
# 170:	learn: 0.0338039	total: 203ms	remaining: 984ms
# 171:	learn: 0.0335306	total: 204ms	remaining: 982ms
# 172:	learn: 0.0332824	total: 205ms	remaining: 979ms
# 173:	learn: 0.0330840	total: 206ms	remaining: 977ms
# 174:	learn: 0.0327681	total: 207ms	remaining: 974ms
# 175:	learn: 0.0326020	total: 208ms	remaining: 972ms
# 176:	learn: 0.0323841	total: 209ms	remaining: 970ms
# 177:	learn: 0.0321677	total: 210ms	remaining: 968ms
# 178:	learn: 0.0319755	total: 211ms	remaining: 966ms
# 179:	learn: 0.0316792	total: 212ms	remaining: 964ms
# 180:	learn: 0.0314268	total: 213ms	remaining: 962ms
# 181:	learn: 0.0312159	total: 214ms	remaining: 961ms
# 182:	learn: 0.0310191	total: 215ms	remaining: 959ms
# 183:	learn: 0.0308353	total: 216ms	remaining: 957ms
# 184:	learn: 0.0305928	total: 217ms	remaining: 954ms
# 185:	learn: 0.0304300	total: 218ms	remaining: 952ms
# 186:	learn: 0.0302207	total: 219ms	remaining: 950ms
# 187:	learn: 0.0300266	total: 219ms	remaining: 948ms
# 188:	learn: 0.0297950	total: 220ms	remaining: 945ms
# 189:	learn: 0.0296472	total: 221ms	remaining: 943ms
# 190:	learn: 0.0294400	total: 222ms	remaining: 941ms
# 191:	learn: 0.0292503	total: 223ms	remaining: 938ms
# 192:	learn: 0.0289967	total: 224ms	remaining: 937ms
# 193:	learn: 0.0288348	total: 225ms	remaining: 935ms
# 194:	learn: 0.0286632	total: 226ms	remaining: 933ms
# 195:	learn: 0.0284544	total: 227ms	remaining: 931ms
# 196:	learn: 0.0283137	total: 228ms	remaining: 930ms
# 197:	learn: 0.0281622	total: 229ms	remaining: 929ms
# 198:	learn: 0.0279485	total: 230ms	remaining: 927ms
# 199:	learn: 0.0278256	total: 231ms	remaining: 925ms
# 200:	learn: 0.0276317	total: 232ms	remaining: 923ms
# 201:	learn: 0.0274860	total: 233ms	remaining: 921ms
# 202:	learn: 0.0273103	total: 234ms	remaining: 920ms
# 203:	learn: 0.0271672	total: 235ms	remaining: 918ms
# 204:	learn: 0.0270255	total: 236ms	remaining: 916ms
# 205:	learn: 0.0268623	total: 237ms	remaining: 915ms
# 206:	learn: 0.0266726	total: 238ms	remaining: 913ms
# 207:	learn: 0.0265155	total: 239ms	remaining: 911ms
# 208:	learn: 0.0263838	total: 240ms	remaining: 909ms
# 209:	learn: 0.0262081	total: 241ms	remaining: 908ms
# 210:	learn: 0.0260256	total: 242ms	remaining: 907ms
# 211:	learn: 0.0258969	total: 243ms	remaining: 905ms
# 212:	learn: 0.0257491	total: 244ms	remaining: 903ms
# 213:	learn: 0.0256117	total: 245ms	remaining: 901ms
# 214:	learn: 0.0255032	total: 246ms	remaining: 899ms
# 215:	learn: 0.0253378	total: 247ms	remaining: 897ms
# 216:	learn: 0.0251489	total: 248ms	remaining: 896ms
# 217:	learn: 0.0250137	total: 249ms	remaining: 893ms
# 218:	learn: 0.0248825	total: 250ms	remaining: 892ms
# 219:	learn: 0.0247910	total: 251ms	remaining: 890ms
# 220:	learn: 0.0246340	total: 252ms	remaining: 888ms
# 221:	learn: 0.0245367	total: 253ms	remaining: 887ms
# 222:	learn: 0.0243973	total: 254ms	remaining: 885ms
# 223:	learn: 0.0242137	total: 255ms	remaining: 884ms
# 224:	learn: 0.0240397	total: 256ms	remaining: 883ms
# 225:	learn: 0.0239110	total: 257ms	remaining: 881ms
# 226:	learn: 0.0237904	total: 258ms	remaining: 880ms
# 227:	learn: 0.0236690	total: 259ms	remaining: 878ms
# 228:	learn: 0.0235531	total: 260ms	remaining: 876ms
# 229:	learn: 0.0233984	total: 261ms	remaining: 875ms
# 230:	learn: 0.0232677	total: 262ms	remaining: 873ms
# 231:	learn: 0.0231328	total: 263ms	remaining: 872ms
# 232:	learn: 0.0229802	total: 264ms	remaining: 870ms
# 233:	learn: 0.0228744	total: 265ms	remaining: 868ms
# 234:	learn: 0.0227693	total: 266ms	remaining: 867ms
# 235:	learn: 0.0226333	total: 267ms	remaining: 865ms
# 236:	learn: 0.0225389	total: 268ms	remaining: 863ms
# 237:	learn: 0.0224289	total: 269ms	remaining: 861ms
# 238:	learn: 0.0223243	total: 270ms	remaining: 860ms
# 239:	learn: 0.0222185	total: 271ms	remaining: 858ms
# 240:	learn: 0.0221195	total: 272ms	remaining: 858ms
# 241:	learn: 0.0219840	total: 273ms	remaining: 856ms
# 242:	learn: 0.0218459	total: 274ms	remaining: 854ms
# 243:	learn: 0.0217446	total: 275ms	remaining: 853ms
# 244:	learn: 0.0216527	total: 276ms	remaining: 852ms
# 245:	learn: 0.0215406	total: 278ms	remaining: 851ms
# 246:	learn: 0.0214487	total: 279ms	remaining: 849ms
# 247:	learn: 0.0213584	total: 279ms	remaining: 847ms
# 248:	learn: 0.0212544	total: 280ms	remaining: 846ms
# 249:	learn: 0.0211347	total: 281ms	remaining: 844ms
# 250:	learn: 0.0210616	total: 282ms	remaining: 843ms
# 251:	learn: 0.0209434	total: 284ms	remaining: 842ms
# 252:	learn: 0.0208502	total: 285ms	remaining: 841ms
# 253:	learn: 0.0207386	total: 286ms	remaining: 839ms
# 254:	learn: 0.0206448	total: 287ms	remaining: 838ms
# 255:	learn: 0.0205551	total: 288ms	remaining: 836ms
# 256:	learn: 0.0204457	total: 289ms	remaining: 834ms
# 257:	learn: 0.0203620	total: 290ms	remaining: 833ms
# 258:	learn: 0.0202815	total: 290ms	remaining: 831ms
# 259:	learn: 0.0202034	total: 291ms	remaining: 829ms
# 260:	learn: 0.0201175	total: 292ms	remaining: 827ms
# 261:	learn: 0.0200351	total: 293ms	remaining: 825ms
# 262:	learn: 0.0199507	total: 294ms	remaining: 823ms
# 263:	learn: 0.0198549	total: 295ms	remaining: 821ms
# 264:	learn: 0.0197776	total: 295ms	remaining: 820ms
# 265:	learn: 0.0196736	total: 296ms	remaining: 818ms
# 266:	learn: 0.0196008	total: 297ms	remaining: 816ms
# 267:	learn: 0.0195253	total: 298ms	remaining: 815ms
# 268:	learn: 0.0194540	total: 299ms	remaining: 813ms
# 269:	learn: 0.0193523	total: 300ms	remaining: 812ms
# 270:	learn: 0.0192683	total: 301ms	remaining: 810ms
# 271:	learn: 0.0191861	total: 302ms	remaining: 809ms
# 272:	learn: 0.0190725	total: 303ms	remaining: 807ms
# 273:	learn: 0.0190053	total: 304ms	remaining: 805ms
# 274:	learn: 0.0189146	total: 305ms	remaining: 804ms
# 275:	learn: 0.0188026	total: 306ms	remaining: 802ms
# 276:	learn: 0.0186896	total: 306ms	remaining: 800ms
# 277:	learn: 0.0186141	total: 307ms	remaining: 798ms
# 278:	learn: 0.0185430	total: 308ms	remaining: 796ms
# 279:	learn: 0.0184676	total: 309ms	remaining: 795ms
# 280:	learn: 0.0183969	total: 310ms	remaining: 793ms
# 281:	learn: 0.0183384	total: 311ms	remaining: 791ms
# 282:	learn: 0.0182594	total: 312ms	remaining: 790ms
# 283:	learn: 0.0181788	total: 313ms	remaining: 788ms
# 284:	learn: 0.0181014	total: 314ms	remaining: 787ms
# 285:	learn: 0.0180279	total: 315ms	remaining: 786ms
# 286:	learn: 0.0179492	total: 316ms	remaining: 784ms
# 287:	learn: 0.0178624	total: 316ms	remaining: 782ms
# 288:	learn: 0.0178055	total: 317ms	remaining: 781ms
# 289:	learn: 0.0177379	total: 318ms	remaining: 779ms
# 290:	learn: 0.0176703	total: 319ms	remaining: 777ms
# 291:	learn: 0.0176093	total: 320ms	remaining: 775ms
# 292:	learn: 0.0175471	total: 321ms	remaining: 774ms
# 293:	learn: 0.0174871	total: 321ms	remaining: 772ms
# 294:	learn: 0.0174075	total: 322ms	remaining: 770ms
# 295:	learn: 0.0173262	total: 323ms	remaining: 769ms
# 296:	learn: 0.0172564	total: 324ms	remaining: 767ms
# 297:	learn: 0.0171959	total: 325ms	remaining: 765ms
# 298:	learn: 0.0171123	total: 326ms	remaining: 764ms
# 299:	learn: 0.0170542	total: 327ms	remaining: 762ms
# 300:	learn: 0.0169860	total: 328ms	remaining: 761ms
# 301:	learn: 0.0169282	total: 329ms	remaining: 760ms
# 302:	learn: 0.0168641	total: 330ms	remaining: 759ms
# 303:	learn: 0.0167933	total: 331ms	remaining: 757ms
# 304:	learn: 0.0167349	total: 332ms	remaining: 755ms
# 305:	learn: 0.0166561	total: 332ms	remaining: 754ms
# 306:	learn: 0.0166083	total: 333ms	remaining: 752ms
# 307:	learn: 0.0165396	total: 334ms	remaining: 751ms
# 308:	learn: 0.0164784	total: 335ms	remaining: 749ms
# 309:	learn: 0.0164127	total: 336ms	remaining: 747ms
# 310:	learn: 0.0163374	total: 337ms	remaining: 746ms
# 311:	learn: 0.0162786	total: 337ms	remaining: 744ms
# 312:	learn: 0.0162083	total: 338ms	remaining: 742ms
# 313:	learn: 0.0161574	total: 339ms	remaining: 741ms
# 314:	learn: 0.0161010	total: 340ms	remaining: 739ms
# 315:	learn: 0.0160553	total: 341ms	remaining: 738ms
# 316:	learn: 0.0159929	total: 342ms	remaining: 737ms
# 317:	learn: 0.0159425	total: 343ms	remaining: 735ms
# 318:	learn: 0.0158929	total: 344ms	remaining: 734ms
# 319:	learn: 0.0158265	total: 345ms	remaining: 733ms
# 320:	learn: 0.0157572	total: 346ms	remaining: 731ms
# 321:	learn: 0.0157087	total: 346ms	remaining: 730ms
# 322:	learn: 0.0156499	total: 347ms	remaining: 728ms
# 323:	learn: 0.0155822	total: 348ms	remaining: 727ms
# 324:	learn: 0.0155415	total: 349ms	remaining: 725ms
# 325:	learn: 0.0154715	total: 350ms	remaining: 724ms
# 326:	learn: 0.0154070	total: 351ms	remaining: 722ms
# 327:	learn: 0.0153442	total: 352ms	remaining: 721ms
# 328:	learn: 0.0153015	total: 352ms	remaining: 719ms
# 329:	learn: 0.0152514	total: 353ms	remaining: 717ms
# 330:	learn: 0.0152024	total: 354ms	remaining: 716ms
# 331:	learn: 0.0151495	total: 356ms	remaining: 717ms
# 332:	learn: 0.0150856	total: 358ms	remaining: 717ms
# 333:	learn: 0.0150349	total: 359ms	remaining: 716ms
# 334:	learn: 0.0149860	total: 360ms	remaining: 714ms
# 335:	learn: 0.0149463	total: 361ms	remaining: 713ms
# 336:	learn: 0.0149030	total: 362ms	remaining: 711ms
# 337:	learn: 0.0148600	total: 362ms	remaining: 710ms
# 338:	learn: 0.0148122	total: 363ms	remaining: 709ms
# 339:	learn: 0.0147673	total: 364ms	remaining: 707ms
# 340:	learn: 0.0147065	total: 365ms	remaining: 706ms
# 341:	learn: 0.0146608	total: 366ms	remaining: 704ms
# 342:	learn: 0.0146072	total: 367ms	remaining: 703ms
# 343:	learn: 0.0145533	total: 368ms	remaining: 701ms
# 344:	learn: 0.0145068	total: 369ms	remaining: 700ms
# 345:	learn: 0.0144703	total: 370ms	remaining: 699ms
# 346:	learn: 0.0144130	total: 371ms	remaining: 698ms
# 347:	learn: 0.0143507	total: 372ms	remaining: 697ms
# 348:	learn: 0.0143113	total: 373ms	remaining: 696ms
# 349:	learn: 0.0142816	total: 374ms	remaining: 695ms
# 350:	learn: 0.0142400	total: 375ms	remaining: 693ms
# 351:	learn: 0.0141895	total: 376ms	remaining: 692ms
# 352:	learn: 0.0141452	total: 377ms	remaining: 690ms
# 353:	learn: 0.0141150	total: 378ms	remaining: 689ms
# 354:	learn: 0.0140785	total: 378ms	remaining: 688ms
# 355:	learn: 0.0140404	total: 379ms	remaining: 686ms
# 356:	learn: 0.0139956	total: 380ms	remaining: 685ms
# 357:	learn: 0.0139410	total: 381ms	remaining: 684ms
# 358:	learn: 0.0138813	total: 382ms	remaining: 682ms
# 359:	learn: 0.0138318	total: 383ms	remaining: 681ms
# 360:	learn: 0.0137909	total: 384ms	remaining: 680ms
# 361:	learn: 0.0137502	total: 385ms	remaining: 679ms
# 362:	learn: 0.0137069	total: 386ms	remaining: 678ms
# 363:	learn: 0.0136591	total: 387ms	remaining: 677ms
# 364:	learn: 0.0136124	total: 388ms	remaining: 676ms
# 365:	learn: 0.0135559	total: 389ms	remaining: 674ms
# 366:	learn: 0.0134997	total: 390ms	remaining: 673ms
# 367:	learn: 0.0134664	total: 391ms	remaining: 672ms
# 368:	learn: 0.0134084	total: 392ms	remaining: 671ms
# 369:	learn: 0.0133714	total: 393ms	remaining: 669ms
# 370:	learn: 0.0133336	total: 394ms	remaining: 668ms
# 371:	learn: 0.0132988	total: 395ms	remaining: 667ms
# 372:	learn: 0.0132662	total: 396ms	remaining: 666ms
# 373:	learn: 0.0132305	total: 397ms	remaining: 665ms
# 374:	learn: 0.0131868	total: 398ms	remaining: 663ms
# 375:	learn: 0.0131497	total: 399ms	remaining: 662ms
# 376:	learn: 0.0131177	total: 400ms	remaining: 661ms
# 377:	learn: 0.0130866	total: 401ms	remaining: 660ms
# 378:	learn: 0.0130456	total: 402ms	remaining: 659ms
# 379:	learn: 0.0129980	total: 403ms	remaining: 658ms
# 380:	learn: 0.0129629	total: 404ms	remaining: 656ms
# 381:	learn: 0.0129243	total: 405ms	remaining: 655ms
# 382:	learn: 0.0128787	total: 406ms	remaining: 654ms
# 383:	learn: 0.0128376	total: 407ms	remaining: 653ms
# 384:	learn: 0.0127982	total: 408ms	remaining: 651ms
# 385:	learn: 0.0127653	total: 409ms	remaining: 650ms
# 386:	learn: 0.0127298	total: 409ms	remaining: 649ms
# 387:	learn: 0.0126833	total: 410ms	remaining: 647ms
# 388:	learn: 0.0126434	total: 411ms	remaining: 646ms
# 389:	learn: 0.0126138	total: 412ms	remaining: 645ms
# 390:	learn: 0.0125913	total: 413ms	remaining: 644ms
# 391:	learn: 0.0125640	total: 414ms	remaining: 643ms
# 392:	learn: 0.0125208	total: 415ms	remaining: 642ms
# 393:	learn: 0.0124827	total: 416ms	remaining: 640ms
# 394:	learn: 0.0124539	total: 417ms	remaining: 639ms
# 395:	learn: 0.0124122	total: 418ms	remaining: 638ms
# 396:	learn: 0.0123781	total: 419ms	remaining: 636ms
# 397:	learn: 0.0123499	total: 420ms	remaining: 635ms
# 398:	learn: 0.0123148	total: 421ms	remaining: 633ms
# 399:	learn: 0.0122723	total: 421ms	remaining: 632ms
# 400:	learn: 0.0122255	total: 422ms	remaining: 631ms
# 401:	learn: 0.0121862	total: 423ms	remaining: 630ms
# 402:	learn: 0.0121498	total: 424ms	remaining: 628ms
# 403:	learn: 0.0121021	total: 425ms	remaining: 627ms
# 404:	learn: 0.0120807	total: 426ms	remaining: 626ms
# 405:	learn: 0.0120555	total: 427ms	remaining: 624ms
# 406:	learn: 0.0120093	total: 428ms	remaining: 623ms
# 407:	learn: 0.0119622	total: 429ms	remaining: 622ms
# 408:	learn: 0.0119272	total: 430ms	remaining: 621ms
# 409:	learn: 0.0118988	total: 431ms	remaining: 620ms
# 410:	learn: 0.0118683	total: 432ms	remaining: 619ms
# 411:	learn: 0.0118337	total: 432ms	remaining: 617ms
# 412:	learn: 0.0118064	total: 433ms	remaining: 616ms
# 413:	learn: 0.0117635	total: 434ms	remaining: 615ms
# 414:	learn: 0.0117348	total: 435ms	remaining: 614ms
# 415:	learn: 0.0117033	total: 436ms	remaining: 613ms
# 416:	learn: 0.0116704	total: 437ms	remaining: 611ms
# 417:	learn: 0.0116384	total: 438ms	remaining: 610ms
# 418:	learn: 0.0116044	total: 439ms	remaining: 609ms
# 419:	learn: 0.0115742	total: 440ms	remaining: 607ms
# 420:	learn: 0.0115289	total: 441ms	remaining: 606ms
# 421:	learn: 0.0114997	total: 442ms	remaining: 605ms
# 422:	learn: 0.0114567	total: 443ms	remaining: 604ms
# 423:	learn: 0.0114319	total: 444ms	remaining: 603ms
# 424:	learn: 0.0113966	total: 445ms	remaining: 601ms
# 425:	learn: 0.0113670	total: 445ms	remaining: 600ms
# 426:	learn: 0.0113366	total: 446ms	remaining: 599ms
# 427:	learn: 0.0113040	total: 447ms	remaining: 597ms
# 428:	learn: 0.0112618	total: 448ms	remaining: 596ms
# 429:	learn: 0.0112380	total: 449ms	remaining: 595ms
# 430:	learn: 0.0112077	total: 450ms	remaining: 594ms
# 431:	learn: 0.0111808	total: 451ms	remaining: 593ms
# 432:	learn: 0.0111436	total: 451ms	remaining: 591ms
# 433:	learn: 0.0111133	total: 452ms	remaining: 590ms
# 434:	learn: 0.0110794	total: 453ms	remaining: 589ms
# 435:	learn: 0.0110546	total: 454ms	remaining: 587ms
# 436:	learn: 0.0110247	total: 455ms	remaining: 586ms
# 437:	learn: 0.0110022	total: 456ms	remaining: 585ms
# 438:	learn: 0.0109818	total: 457ms	remaining: 584ms
# 439:	learn: 0.0109560	total: 458ms	remaining: 583ms
# 440:	learn: 0.0109282	total: 459ms	remaining: 581ms
# 441:	learn: 0.0109008	total: 460ms	remaining: 580ms
# 442:	learn: 0.0108751	total: 460ms	remaining: 579ms
# 443:	learn: 0.0108476	total: 461ms	remaining: 578ms
# 444:	learn: 0.0108180	total: 462ms	remaining: 576ms
# 445:	learn: 0.0107938	total: 463ms	remaining: 575ms
# 446:	learn: 0.0107693	total: 464ms	remaining: 574ms
# 447:	learn: 0.0107462	total: 465ms	remaining: 573ms
# 448:	learn: 0.0107145	total: 466ms	remaining: 572ms
# 449:	learn: 0.0106871	total: 467ms	remaining: 571ms
# 450:	learn: 0.0106571	total: 468ms	remaining: 569ms
# 451:	learn: 0.0106366	total: 468ms	remaining: 568ms
# 452:	learn: 0.0106150	total: 469ms	remaining: 567ms
# 453:	learn: 0.0105919	total: 470ms	remaining: 566ms
# 454:	learn: 0.0105713	total: 471ms	remaining: 565ms
# 455:	learn: 0.0105446	total: 472ms	remaining: 563ms
# 456:	learn: 0.0105154	total: 473ms	remaining: 562ms
# 457:	learn: 0.0104879	total: 474ms	remaining: 561ms
# 458:	learn: 0.0104717	total: 475ms	remaining: 560ms
# 459:	learn: 0.0104430	total: 476ms	remaining: 559ms
# 460:	learn: 0.0104206	total: 477ms	remaining: 558ms
# 461:	learn: 0.0103968	total: 478ms	remaining: 556ms
# 462:	learn: 0.0103755	total: 479ms	remaining: 555ms
# 463:	learn: 0.0103480	total: 479ms	remaining: 554ms
# 464:	learn: 0.0103239	total: 480ms	remaining: 553ms
# 465:	learn: 0.0102889	total: 481ms	remaining: 551ms
# 466:	learn: 0.0102554	total: 482ms	remaining: 550ms
# 467:	learn: 0.0102316	total: 483ms	remaining: 549ms
# 468:	learn: 0.0101967	total: 484ms	remaining: 548ms
# 469:	learn: 0.0101741	total: 485ms	remaining: 546ms
# 470:	learn: 0.0101465	total: 486ms	remaining: 545ms
# 471:	learn: 0.0101129	total: 487ms	remaining: 544ms
# 472:	learn: 0.0100798	total: 487ms	remaining: 543ms
# 473:	learn: 0.0100563	total: 488ms	remaining: 542ms
# 474:	learn: 0.0100291	total: 489ms	remaining: 541ms
# 475:	learn: 0.0100018	total: 490ms	remaining: 540ms
# 476:	learn: 0.0099766	total: 491ms	remaining: 539ms
# 477:	learn: 0.0099526	total: 492ms	remaining: 537ms
# 478:	learn: 0.0099305	total: 493ms	remaining: 536ms
# 479:	learn: 0.0099113	total: 494ms	remaining: 535ms
# 480:	learn: 0.0098890	total: 495ms	remaining: 534ms
# 481:	learn: 0.0098675	total: 496ms	remaining: 533ms
# 482:	learn: 0.0098417	total: 497ms	remaining: 532ms
# 483:	learn: 0.0098127	total: 498ms	remaining: 531ms
# 484:	learn: 0.0097878	total: 499ms	remaining: 530ms
# 485:	learn: 0.0097584	total: 500ms	remaining: 529ms
# 486:	learn: 0.0097376	total: 501ms	remaining: 528ms
# 487:	learn: 0.0097084	total: 502ms	remaining: 527ms
# 488:	learn: 0.0096899	total: 503ms	remaining: 526ms
# 489:	learn: 0.0096686	total: 504ms	remaining: 525ms
# 490:	learn: 0.0096437	total: 505ms	remaining: 524ms
# 491:	learn: 0.0096222	total: 506ms	remaining: 523ms
# 492:	learn: 0.0095990	total: 507ms	remaining: 521ms
# 493:	learn: 0.0095674	total: 508ms	remaining: 520ms
# 494:	learn: 0.0095407	total: 509ms	remaining: 519ms
# 495:	learn: 0.0095232	total: 510ms	remaining: 518ms
# 496:	learn: 0.0095001	total: 510ms	remaining: 517ms
# 497:	learn: 0.0094705	total: 511ms	remaining: 515ms
# 498:	learn: 0.0094486	total: 512ms	remaining: 514ms
# 499:	learn: 0.0094358	total: 513ms	remaining: 513ms
# 500:	learn: 0.0094172	total: 514ms	remaining: 512ms
# 501:	learn: 0.0093957	total: 515ms	remaining: 511ms
# 502:	learn: 0.0093694	total: 516ms	remaining: 510ms
# 503:	learn: 0.0093459	total: 518ms	remaining: 509ms
# 504:	learn: 0.0093243	total: 519ms	remaining: 508ms
# 505:	learn: 0.0093083	total: 519ms	remaining: 507ms
# 506:	learn: 0.0092931	total: 520ms	remaining: 506ms
# 507:	learn: 0.0092706	total: 521ms	remaining: 505ms
# 508:	learn: 0.0092468	total: 522ms	remaining: 503ms
# 509:	learn: 0.0092257	total: 523ms	remaining: 502ms
# 510:	learn: 0.0092095	total: 524ms	remaining: 501ms
# 511:	learn: 0.0091914	total: 524ms	remaining: 500ms
# 512:	learn: 0.0091648	total: 525ms	remaining: 499ms
# 513:	learn: 0.0091451	total: 526ms	remaining: 498ms
# 514:	learn: 0.0091185	total: 527ms	remaining: 496ms
# 515:	learn: 0.0091013	total: 528ms	remaining: 495ms
# 516:	learn: 0.0090802	total: 529ms	remaining: 494ms
# 517:	learn: 0.0090611	total: 530ms	remaining: 493ms
# 518:	learn: 0.0090362	total: 531ms	remaining: 492ms
# 519:	learn: 0.0090209	total: 532ms	remaining: 491ms
# 520:	learn: 0.0090029	total: 533ms	remaining: 490ms
# 521:	learn: 0.0089840	total: 534ms	remaining: 489ms
# 522:	learn: 0.0089608	total: 535ms	remaining: 488ms
# 523:	learn: 0.0089451	total: 535ms	remaining: 486ms
# 524:	learn: 0.0089262	total: 536ms	remaining: 485ms
# 525:	learn: 0.0089110	total: 537ms	remaining: 484ms
# 526:	learn: 0.0088983	total: 538ms	remaining: 483ms
# 527:	learn: 0.0088805	total: 539ms	remaining: 482ms
# 528:	learn: 0.0088540	total: 540ms	remaining: 481ms
# 529:	learn: 0.0088366	total: 541ms	remaining: 479ms
# 530:	learn: 0.0088130	total: 541ms	remaining: 478ms
# 531:	learn: 0.0087977	total: 542ms	remaining: 477ms
# 532:	learn: 0.0087816	total: 544ms	remaining: 477ms
# 533:	learn: 0.0087604	total: 546ms	remaining: 476ms
# 534:	learn: 0.0087393	total: 547ms	remaining: 475ms
# 535:	learn: 0.0087131	total: 548ms	remaining: 474ms
# 536:	learn: 0.0086963	total: 549ms	remaining: 473ms
# 537:	learn: 0.0086807	total: 550ms	remaining: 472ms
# 538:	learn: 0.0086616	total: 550ms	remaining: 471ms
# 539:	learn: 0.0086450	total: 551ms	remaining: 470ms
# 540:	learn: 0.0086266	total: 552ms	remaining: 468ms
# 541:	learn: 0.0086112	total: 553ms	remaining: 467ms
# 542:	learn: 0.0085929	total: 554ms	remaining: 466ms
# 543:	learn: 0.0085730	total: 555ms	remaining: 465ms
# 544:	learn: 0.0085468	total: 555ms	remaining: 464ms
# 545:	learn: 0.0085268	total: 556ms	remaining: 463ms
# 546:	learn: 0.0085125	total: 558ms	remaining: 462ms
# 547:	learn: 0.0084956	total: 559ms	remaining: 461ms
# 548:	learn: 0.0084699	total: 560ms	remaining: 460ms
# 549:	learn: 0.0084575	total: 561ms	remaining: 459ms
# 550:	learn: 0.0084410	total: 562ms	remaining: 458ms
# 551:	learn: 0.0084239	total: 562ms	remaining: 456ms
# 552:	learn: 0.0084074	total: 563ms	remaining: 455ms
# 553:	learn: 0.0083869	total: 564ms	remaining: 454ms
# 554:	learn: 0.0083634	total: 565ms	remaining: 453ms
# 555:	learn: 0.0083477	total: 566ms	remaining: 452ms
# 556:	learn: 0.0083352	total: 567ms	remaining: 451ms
# 557:	learn: 0.0083202	total: 568ms	remaining: 450ms
# 558:	learn: 0.0083003	total: 568ms	remaining: 448ms
# 559:	learn: 0.0082896	total: 569ms	remaining: 447ms
# 560:	learn: 0.0082677	total: 570ms	remaining: 446ms
# 561:	learn: 0.0082516	total: 571ms	remaining: 445ms
# 562:	learn: 0.0082312	total: 572ms	remaining: 444ms
# 563:	learn: 0.0082109	total: 573ms	remaining: 443ms
# 564:	learn: 0.0081935	total: 575ms	remaining: 442ms
# 565:	learn: 0.0081775	total: 575ms	remaining: 441ms
# 566:	learn: 0.0081620	total: 576ms	remaining: 440ms
# 567:	learn: 0.0081418	total: 577ms	remaining: 439ms
# 568:	learn: 0.0081266	total: 578ms	remaining: 438ms
# 569:	learn: 0.0081038	total: 579ms	remaining: 437ms
# 570:	learn: 0.0080899	total: 580ms	remaining: 435ms
# 571:	learn: 0.0080789	total: 580ms	remaining: 434ms
# 572:	learn: 0.0080641	total: 581ms	remaining: 433ms
# 573:	learn: 0.0080472	total: 582ms	remaining: 432ms
# 574:	learn: 0.0080300	total: 583ms	remaining: 431ms
# 575:	learn: 0.0080160	total: 584ms	remaining: 430ms
# 576:	learn: 0.0079979	total: 585ms	remaining: 429ms
# 577:	learn: 0.0079768	total: 586ms	remaining: 428ms
# 578:	learn: 0.0079598	total: 587ms	remaining: 427ms
# 579:	learn: 0.0079476	total: 588ms	remaining: 426ms
# 580:	learn: 0.0079332	total: 589ms	remaining: 425ms
# 581:	learn: 0.0079198	total: 589ms	remaining: 423ms
# 582:	learn: 0.0079050	total: 590ms	remaining: 422ms
# 583:	learn: 0.0078900	total: 591ms	remaining: 421ms
# 584:	learn: 0.0078758	total: 592ms	remaining: 420ms
# 585:	learn: 0.0078586	total: 593ms	remaining: 419ms
# 586:	learn: 0.0078469	total: 594ms	remaining: 418ms
# 587:	learn: 0.0078272	total: 595ms	remaining: 417ms
# 588:	learn: 0.0078139	total: 595ms	remaining: 415ms
# 589:	learn: 0.0077963	total: 596ms	remaining: 414ms
# 590:	learn: 0.0077807	total: 597ms	remaining: 413ms
# 591:	learn: 0.0077663	total: 598ms	remaining: 412ms
# 592:	learn: 0.0077518	total: 599ms	remaining: 411ms
# 593:	learn: 0.0077361	total: 600ms	remaining: 410ms
# 594:	learn: 0.0077238	total: 601ms	remaining: 409ms
# 595:	learn: 0.0077031	total: 602ms	remaining: 408ms
# 596:	learn: 0.0076925	total: 603ms	remaining: 407ms
# 597:	learn: 0.0076766	total: 604ms	remaining: 406ms
# 598:	learn: 0.0076601	total: 605ms	remaining: 405ms
# 599:	learn: 0.0076455	total: 605ms	remaining: 404ms
# 600:	learn: 0.0076293	total: 606ms	remaining: 402ms
# 601:	learn: 0.0076132	total: 607ms	remaining: 401ms
# 602:	learn: 0.0075998	total: 608ms	remaining: 400ms
# 603:	learn: 0.0075888	total: 609ms	remaining: 399ms
# 604:	learn: 0.0075751	total: 610ms	remaining: 398ms
# 605:	learn: 0.0075606	total: 611ms	remaining: 397ms
# 606:	learn: 0.0075486	total: 611ms	remaining: 396ms
# 607:	learn: 0.0075372	total: 612ms	remaining: 395ms
# 608:	learn: 0.0075229	total: 613ms	remaining: 394ms
# 609:	learn: 0.0075057	total: 614ms	remaining: 393ms
# 610:	learn: 0.0074946	total: 615ms	remaining: 392ms
# 611:	learn: 0.0074838	total: 616ms	remaining: 391ms
# 612:	learn: 0.0074723	total: 617ms	remaining: 389ms
# 613:	learn: 0.0074630	total: 618ms	remaining: 388ms
# 614:	learn: 0.0074534	total: 619ms	remaining: 387ms
# 615:	learn: 0.0074417	total: 619ms	remaining: 386ms
# 616:	learn: 0.0074233	total: 620ms	remaining: 385ms
# 617:	learn: 0.0074096	total: 621ms	remaining: 384ms
# 618:	learn: 0.0073962	total: 622ms	remaining: 383ms
# 619:	learn: 0.0073844	total: 623ms	remaining: 382ms
# 620:	learn: 0.0073708	total: 624ms	remaining: 381ms
# 621:	learn: 0.0073577	total: 625ms	remaining: 380ms
# 622:	learn: 0.0073461	total: 626ms	remaining: 379ms
# 623:	learn: 0.0073305	total: 626ms	remaining: 377ms
# 624:	learn: 0.0073186	total: 627ms	remaining: 376ms
# 625:	learn: 0.0073019	total: 628ms	remaining: 375ms
# 626:	learn: 0.0072896	total: 629ms	remaining: 374ms
# 627:	learn: 0.0072771	total: 630ms	remaining: 373ms
# 628:	learn: 0.0072593	total: 631ms	remaining: 372ms
# 629:	learn: 0.0072474	total: 632ms	remaining: 371ms
# 630:	learn: 0.0072359	total: 633ms	remaining: 370ms
# 631:	learn: 0.0072245	total: 634ms	remaining: 369ms
# 632:	learn: 0.0072139	total: 635ms	remaining: 368ms
# 633:	learn: 0.0072061	total: 635ms	remaining: 367ms
# 634:	learn: 0.0071895	total: 636ms	remaining: 366ms
# 635:	learn: 0.0071752	total: 637ms	remaining: 365ms
# 636:	learn: 0.0071634	total: 638ms	remaining: 364ms
# 637:	learn: 0.0071504	total: 639ms	remaining: 363ms
# 638:	learn: 0.0071399	total: 640ms	remaining: 362ms
# 639:	learn: 0.0071281	total: 641ms	remaining: 361ms
# 640:	learn: 0.0071165	total: 642ms	remaining: 359ms
# 641:	learn: 0.0071020	total: 643ms	remaining: 358ms
# 642:	learn: 0.0070897	total: 644ms	remaining: 357ms
# 643:	learn: 0.0070827	total: 645ms	remaining: 356ms
# 644:	learn: 0.0070695	total: 646ms	remaining: 355ms
# 645:	learn: 0.0070590	total: 647ms	remaining: 354ms
# 646:	learn: 0.0070482	total: 647ms	remaining: 353ms
# 647:	learn: 0.0070385	total: 648ms	remaining: 352ms
# 648:	learn: 0.0070243	total: 649ms	remaining: 351ms
# 649:	learn: 0.0070115	total: 650ms	remaining: 350ms
# 650:	learn: 0.0070019	total: 651ms	remaining: 349ms
# 651:	learn: 0.0069912	total: 652ms	remaining: 348ms
# 652:	learn: 0.0069769	total: 653ms	remaining: 347ms
# 653:	learn: 0.0069654	total: 654ms	remaining: 346ms
# 654:	learn: 0.0069540	total: 654ms	remaining: 345ms
# 655:	learn: 0.0069420	total: 655ms	remaining: 344ms
# 656:	learn: 0.0069326	total: 656ms	remaining: 342ms
# 657:	learn: 0.0069217	total: 657ms	remaining: 341ms
# 658:	learn: 0.0069080	total: 658ms	remaining: 341ms
# 659:	learn: 0.0068983	total: 659ms	remaining: 340ms
# 660:	learn: 0.0068893	total: 660ms	remaining: 339ms
# 661:	learn: 0.0068735	total: 661ms	remaining: 337ms
# 662:	learn: 0.0068601	total: 662ms	remaining: 336ms
# 663:	learn: 0.0068439	total: 663ms	remaining: 335ms
# 664:	learn: 0.0068334	total: 664ms	remaining: 334ms
# 665:	learn: 0.0068188	total: 664ms	remaining: 333ms
# 666:	learn: 0.0068080	total: 665ms	remaining: 332ms
# 667:	learn: 0.0067931	total: 666ms	remaining: 331ms
# 668:	learn: 0.0067843	total: 667ms	remaining: 330ms
# 669:	learn: 0.0067756	total: 668ms	remaining: 329ms
# 670:	learn: 0.0067618	total: 669ms	remaining: 328ms
# 671:	learn: 0.0067527	total: 670ms	remaining: 327ms
# 672:	learn: 0.0067372	total: 670ms	remaining: 326ms
# 673:	learn: 0.0067253	total: 671ms	remaining: 325ms
# 674:	learn: 0.0067160	total: 672ms	remaining: 324ms
# 675:	learn: 0.0067038	total: 673ms	remaining: 323ms
# 676:	learn: 0.0066935	total: 674ms	remaining: 322ms
# 677:	learn: 0.0066826	total: 675ms	remaining: 321ms
# 678:	learn: 0.0066740	total: 676ms	remaining: 320ms
# 679:	learn: 0.0066604	total: 677ms	remaining: 318ms
# 680:	learn: 0.0066493	total: 678ms	remaining: 317ms
# 681:	learn: 0.0066400	total: 679ms	remaining: 316ms
# 682:	learn: 0.0066317	total: 680ms	remaining: 315ms
# 683:	learn: 0.0066212	total: 681ms	remaining: 314ms
# 684:	learn: 0.0066075	total: 681ms	remaining: 313ms
# 685:	learn: 0.0065983	total: 682ms	remaining: 312ms
# 686:	learn: 0.0065880	total: 683ms	remaining: 311ms
# 687:	learn: 0.0065790	total: 684ms	remaining: 310ms
# 688:	learn: 0.0065692	total: 685ms	remaining: 309ms
# 689:	learn: 0.0065560	total: 686ms	remaining: 308ms
# 690:	learn: 0.0065436	total: 687ms	remaining: 307ms
# 691:	learn: 0.0065326	total: 688ms	remaining: 306ms
# 692:	learn: 0.0065180	total: 689ms	remaining: 305ms
# 693:	learn: 0.0065071	total: 690ms	remaining: 304ms
# 694:	learn: 0.0065007	total: 691ms	remaining: 303ms
# 695:	learn: 0.0064920	total: 691ms	remaining: 302ms
# 696:	learn: 0.0064826	total: 692ms	remaining: 301ms
# 697:	learn: 0.0064710	total: 693ms	remaining: 300ms
# 698:	learn: 0.0064610	total: 694ms	remaining: 299ms
# 699:	learn: 0.0064512	total: 695ms	remaining: 298ms
# 700:	learn: 0.0064419	total: 696ms	remaining: 297ms
# 701:	learn: 0.0064283	total: 697ms	remaining: 296ms
# 702:	learn: 0.0064150	total: 698ms	remaining: 295ms
# 703:	learn: 0.0064035	total: 699ms	remaining: 294ms
# 704:	learn: 0.0063946	total: 699ms	remaining: 293ms
# 705:	learn: 0.0063871	total: 700ms	remaining: 292ms
# 706:	learn: 0.0063734	total: 701ms	remaining: 291ms
# 707:	learn: 0.0063637	total: 702ms	remaining: 290ms
# 708:	learn: 0.0063539	total: 703ms	remaining: 289ms
# 709:	learn: 0.0063441	total: 704ms	remaining: 288ms
# 710:	learn: 0.0063315	total: 705ms	remaining: 287ms
# 711:	learn: 0.0063203	total: 706ms	remaining: 286ms
# 712:	learn: 0.0063058	total: 707ms	remaining: 285ms
# 713:	learn: 0.0062972	total: 708ms	remaining: 284ms
# 714:	learn: 0.0062880	total: 709ms	remaining: 283ms
# 715:	learn: 0.0062749	total: 710ms	remaining: 281ms
# 716:	learn: 0.0062646	total: 710ms	remaining: 280ms
# 717:	learn: 0.0062554	total: 711ms	remaining: 279ms
# 718:	learn: 0.0062478	total: 712ms	remaining: 278ms
# 719:	learn: 0.0062365	total: 713ms	remaining: 277ms
# 720:	learn: 0.0062240	total: 714ms	remaining: 276ms
# 721:	learn: 0.0062151	total: 715ms	remaining: 275ms
# 722:	learn: 0.0062073	total: 716ms	remaining: 274ms
# 723:	learn: 0.0061947	total: 717ms	remaining: 273ms
# 724:	learn: 0.0061868	total: 718ms	remaining: 272ms
# 725:	learn: 0.0061764	total: 718ms	remaining: 271ms
# 726:	learn: 0.0061686	total: 719ms	remaining: 270ms
# 727:	learn: 0.0061583	total: 720ms	remaining: 269ms
# 728:	learn: 0.0061498	total: 721ms	remaining: 268ms
# 729:	learn: 0.0061420	total: 722ms	remaining: 267ms
# 730:	learn: 0.0061343	total: 723ms	remaining: 266ms
# 731:	learn: 0.0061264	total: 724ms	remaining: 265ms
# 732:	learn: 0.0061178	total: 725ms	remaining: 264ms
# 733:	learn: 0.0061082	total: 726ms	remaining: 263ms
# 734:	learn: 0.0060999	total: 726ms	remaining: 262ms
# 735:	learn: 0.0060874	total: 727ms	remaining: 261ms
# 736:	learn: 0.0060782	total: 728ms	remaining: 260ms
# 737:	learn: 0.0060682	total: 729ms	remaining: 259ms
# 738:	learn: 0.0060613	total: 730ms	remaining: 258ms
# 739:	learn: 0.0060507	total: 731ms	remaining: 257ms
# 740:	learn: 0.0060413	total: 732ms	remaining: 256ms
# 741:	learn: 0.0060348	total: 734ms	remaining: 255ms
# 742:	learn: 0.0060267	total: 735ms	remaining: 254ms
# 743:	learn: 0.0060158	total: 736ms	remaining: 253ms
# 744:	learn: 0.0060093	total: 737ms	remaining: 252ms
# 745:	learn: 0.0060015	total: 737ms	remaining: 251ms
# 746:	learn: 0.0059904	total: 738ms	remaining: 250ms
# 747:	learn: 0.0059774	total: 739ms	remaining: 249ms
# 748:	learn: 0.0059672	total: 740ms	remaining: 248ms
# 749:	learn: 0.0059590	total: 741ms	remaining: 247ms
# 750:	learn: 0.0059516	total: 742ms	remaining: 246ms
# 751:	learn: 0.0059439	total: 742ms	remaining: 245ms
# 752:	learn: 0.0059358	total: 743ms	remaining: 244ms
# 753:	learn: 0.0059262	total: 744ms	remaining: 243ms
# 754:	learn: 0.0059195	total: 745ms	remaining: 242ms
# 755:	learn: 0.0059097	total: 746ms	remaining: 241ms
# 756:	learn: 0.0058978	total: 748ms	remaining: 240ms
# 757:	learn: 0.0058857	total: 749ms	remaining: 239ms
# 758:	learn: 0.0058783	total: 749ms	remaining: 238ms
# 759:	learn: 0.0058706	total: 750ms	remaining: 237ms
# 760:	learn: 0.0058595	total: 751ms	remaining: 236ms
# 761:	learn: 0.0058496	total: 752ms	remaining: 235ms
# 762:	learn: 0.0058412	total: 753ms	remaining: 234ms
# 763:	learn: 0.0058314	total: 754ms	remaining: 233ms
# 764:	learn: 0.0058230	total: 755ms	remaining: 232ms
# 765:	learn: 0.0058162	total: 755ms	remaining: 231ms
# 766:	learn: 0.0058065	total: 756ms	remaining: 230ms
# 767:	learn: 0.0057953	total: 757ms	remaining: 229ms
# 768:	learn: 0.0057880	total: 758ms	remaining: 228ms
# 769:	learn: 0.0057807	total: 759ms	remaining: 227ms
# 770:	learn: 0.0057745	total: 760ms	remaining: 226ms
# 771:	learn: 0.0057674	total: 761ms	remaining: 225ms
# 772:	learn: 0.0057594	total: 762ms	remaining: 224ms
# 773:	learn: 0.0057497	total: 763ms	remaining: 223ms
# 774:	learn: 0.0057407	total: 764ms	remaining: 222ms
# 775:	learn: 0.0057342	total: 765ms	remaining: 221ms
# 776:	learn: 0.0057264	total: 766ms	remaining: 220ms
# 777:	learn: 0.0057173	total: 767ms	remaining: 219ms
# 778:	learn: 0.0057078	total: 767ms	remaining: 218ms
# 779:	learn: 0.0056998	total: 768ms	remaining: 217ms
# 780:	learn: 0.0056936	total: 769ms	remaining: 216ms
# 781:	learn: 0.0056839	total: 770ms	remaining: 215ms
# 782:	learn: 0.0056772	total: 771ms	remaining: 214ms
# 783:	learn: 0.0056667	total: 772ms	remaining: 213ms
# 784:	learn: 0.0056603	total: 773ms	remaining: 212ms
# 785:	learn: 0.0056540	total: 774ms	remaining: 211ms
# 786:	learn: 0.0056474	total: 775ms	remaining: 210ms
# 787:	learn: 0.0056373	total: 776ms	remaining: 209ms
# 788:	learn: 0.0056305	total: 776ms	remaining: 208ms
# 789:	learn: 0.0056217	total: 777ms	remaining: 207ms
# 790:	learn: 0.0056108	total: 778ms	remaining: 206ms
# 791:	learn: 0.0056020	total: 779ms	remaining: 205ms
# 792:	learn: 0.0055917	total: 780ms	remaining: 204ms
# 793:	learn: 0.0055858	total: 781ms	remaining: 203ms
# 794:	learn: 0.0055781	total: 782ms	remaining: 202ms
# 795:	learn: 0.0055724	total: 782ms	remaining: 201ms
# 796:	learn: 0.0055636	total: 783ms	remaining: 199ms
# 797:	learn: 0.0055550	total: 784ms	remaining: 198ms
# 798:	learn: 0.0055476	total: 785ms	remaining: 197ms
# 799:	learn: 0.0055412	total: 786ms	remaining: 196ms
# 800:	learn: 0.0055349	total: 787ms	remaining: 195ms
# 801:	learn: 0.0055253	total: 788ms	remaining: 194ms
# 802:	learn: 0.0055194	total: 789ms	remaining: 194ms
# 803:	learn: 0.0055128	total: 790ms	remaining: 193ms
# 804:	learn: 0.0055063	total: 791ms	remaining: 192ms
# 805:	learn: 0.0054947	total: 792ms	remaining: 191ms
# 806:	learn: 0.0054853	total: 792ms	remaining: 190ms
# 807:	learn: 0.0054760	total: 793ms	remaining: 189ms
# 808:	learn: 0.0054690	total: 794ms	remaining: 188ms
# 809:	learn: 0.0054607	total: 795ms	remaining: 187ms
# 810:	learn: 0.0054536	total: 796ms	remaining: 185ms
# 811:	learn: 0.0054470	total: 797ms	remaining: 184ms
# 812:	learn: 0.0054411	total: 798ms	remaining: 183ms
# 813:	learn: 0.0054354	total: 798ms	remaining: 182ms
# 814:	learn: 0.0054278	total: 799ms	remaining: 181ms
# 815:	learn: 0.0054188	total: 800ms	remaining: 180ms
# 816:	learn: 0.0054131	total: 801ms	remaining: 179ms
# 817:	learn: 0.0054055	total: 802ms	remaining: 178ms
# 818:	learn: 0.0053960	total: 804ms	remaining: 178ms
# 819:	learn: 0.0053901	total: 805ms	remaining: 177ms
# 820:	learn: 0.0053848	total: 806ms	remaining: 176ms
# 821:	learn: 0.0053767	total: 806ms	remaining: 175ms
# 822:	learn: 0.0053692	total: 807ms	remaining: 174ms
# 823:	learn: 0.0053618	total: 808ms	remaining: 173ms
# 824:	learn: 0.0053557	total: 809ms	remaining: 172ms
# 825:	learn: 0.0053492	total: 810ms	remaining: 171ms
# 826:	learn: 0.0053437	total: 811ms	remaining: 170ms
# 827:	learn: 0.0053381	total: 812ms	remaining: 169ms
# 828:	learn: 0.0053296	total: 813ms	remaining: 168ms
# 829:	learn: 0.0053205	total: 814ms	remaining: 167ms
# 830:	learn: 0.0053135	total: 815ms	remaining: 166ms
# 831:	learn: 0.0053069	total: 816ms	remaining: 165ms
# 832:	learn: 0.0053002	total: 817ms	remaining: 164ms
# 833:	learn: 0.0052925	total: 818ms	remaining: 163ms
# 834:	learn: 0.0052855	total: 819ms	remaining: 162ms
# 835:	learn: 0.0052788	total: 820ms	remaining: 161ms
# 836:	learn: 0.0052734	total: 820ms	remaining: 160ms
# 837:	learn: 0.0052661	total: 821ms	remaining: 159ms
# 838:	learn: 0.0052571	total: 822ms	remaining: 158ms
# 839:	learn: 0.0052506	total: 823ms	remaining: 157ms
# 840:	learn: 0.0052426	total: 824ms	remaining: 156ms
# 841:	learn: 0.0052361	total: 825ms	remaining: 155ms
# 842:	learn: 0.0052295	total: 826ms	remaining: 154ms
# 843:	learn: 0.0052209	total: 827ms	remaining: 153ms
# 844:	learn: 0.0052119	total: 827ms	remaining: 152ms
# 845:	learn: 0.0052030	total: 829ms	remaining: 151ms
# 846:	learn: 0.0051954	total: 830ms	remaining: 150ms
# 847:	learn: 0.0051881	total: 831ms	remaining: 149ms
# 848:	learn: 0.0051807	total: 831ms	remaining: 148ms
# 849:	learn: 0.0051729	total: 832ms	remaining: 147ms
# 850:	learn: 0.0051656	total: 833ms	remaining: 146ms
# 851:	learn: 0.0051603	total: 834ms	remaining: 145ms
# 852:	learn: 0.0051534	total: 835ms	remaining: 144ms
# 853:	learn: 0.0051471	total: 836ms	remaining: 143ms
# 854:	learn: 0.0051412	total: 837ms	remaining: 142ms
# 855:	learn: 0.0051336	total: 837ms	remaining: 141ms
# 856:	learn: 0.0051263	total: 838ms	remaining: 140ms
# 857:	learn: 0.0051197	total: 839ms	remaining: 139ms
# 858:	learn: 0.0051113	total: 840ms	remaining: 138ms
# 859:	learn: 0.0051046	total: 841ms	remaining: 137ms
# 860:	learn: 0.0050975	total: 842ms	remaining: 136ms
# 861:	learn: 0.0050909	total: 843ms	remaining: 135ms
# 862:	learn: 0.0050846	total: 844ms	remaining: 134ms
# 863:	learn: 0.0050762	total: 845ms	remaining: 133ms
# 864:	learn: 0.0050701	total: 846ms	remaining: 132ms
# 865:	learn: 0.0050645	total: 847ms	remaining: 131ms
# 866:	learn: 0.0050597	total: 848ms	remaining: 130ms
# 867:	learn: 0.0050526	total: 849ms	remaining: 129ms
# 868:	learn: 0.0050464	total: 850ms	remaining: 128ms
# 869:	learn: 0.0050379	total: 851ms	remaining: 127ms
# 870:	learn: 0.0050326	total: 852ms	remaining: 126ms
# 871:	learn: 0.0050266	total: 853ms	remaining: 125ms
# 872:	learn: 0.0050183	total: 854ms	remaining: 124ms
# 873:	learn: 0.0050136	total: 855ms	remaining: 123ms
# 874:	learn: 0.0050053	total: 856ms	remaining: 122ms
# 875:	learn: 0.0049997	total: 857ms	remaining: 121ms
# 876:	learn: 0.0049919	total: 858ms	remaining: 120ms
# 877:	learn: 0.0049856	total: 859ms	remaining: 119ms
# 878:	learn: 0.0049809	total: 860ms	remaining: 118ms
# 879:	learn: 0.0049751	total: 861ms	remaining: 117ms
# 880:	learn: 0.0049696	total: 862ms	remaining: 116ms
# 881:	learn: 0.0049624	total: 863ms	remaining: 115ms
# 882:	learn: 0.0049580	total: 864ms	remaining: 114ms
# 883:	learn: 0.0049507	total: 864ms	remaining: 113ms
# 884:	learn: 0.0049438	total: 865ms	remaining: 112ms
# 885:	learn: 0.0049381	total: 866ms	remaining: 111ms
# 886:	learn: 0.0049318	total: 867ms	remaining: 111ms
# 887:	learn: 0.0049265	total: 868ms	remaining: 110ms
# 888:	learn: 0.0049208	total: 869ms	remaining: 109ms
# 889:	learn: 0.0049154	total: 870ms	remaining: 108ms
# 890:	learn: 0.0049086	total: 871ms	remaining: 107ms
# 891:	learn: 0.0049031	total: 872ms	remaining: 106ms
# 892:	learn: 0.0048961	total: 873ms	remaining: 105ms
# 893:	learn: 0.0048884	total: 874ms	remaining: 104ms
# 894:	learn: 0.0048826	total: 875ms	remaining: 103ms
# 895:	learn: 0.0048773	total: 876ms	remaining: 102ms
# 896:	learn: 0.0048713	total: 877ms	remaining: 101ms
# 897:	learn: 0.0048654	total: 878ms	remaining: 99.7ms
# 898:	learn: 0.0048588	total: 879ms	remaining: 98.8ms
# 899:	learn: 0.0048543	total: 880ms	remaining: 97.8ms
# 900:	learn: 0.0048494	total: 881ms	remaining: 96.8ms
# 901:	learn: 0.0048425	total: 882ms	remaining: 95.8ms
# 902:	learn: 0.0048370	total: 883ms	remaining: 94.9ms
# 903:	learn: 0.0048319	total: 884ms	remaining: 93.9ms
# 904:	learn: 0.0048257	total: 885ms	remaining: 92.9ms
# 905:	learn: 0.0048206	total: 886ms	remaining: 91.9ms
# 906:	learn: 0.0048163	total: 887ms	remaining: 90.9ms
# 907:	learn: 0.0048111	total: 888ms	remaining: 90ms
# 908:	learn: 0.0048067	total: 889ms	remaining: 89ms
# 909:	learn: 0.0048006	total: 890ms	remaining: 88ms
# 910:	learn: 0.0047956	total: 891ms	remaining: 87ms
# 911:	learn: 0.0047881	total: 892ms	remaining: 86ms
# 912:	learn: 0.0047835	total: 893ms	remaining: 85.1ms
# 913:	learn: 0.0047758	total: 894ms	remaining: 84.1ms
# 914:	learn: 0.0047707	total: 895ms	remaining: 83.1ms
# 915:	learn: 0.0047649	total: 895ms	remaining: 82.1ms
# 916:	learn: 0.0047571	total: 896ms	remaining: 81.1ms
# 917:	learn: 0.0047497	total: 897ms	remaining: 80.1ms
# 918:	learn: 0.0047421	total: 898ms	remaining: 79.1ms
# 919:	learn: 0.0047381	total: 899ms	remaining: 78.2ms
# 920:	learn: 0.0047329	total: 900ms	remaining: 77.2ms
# 921:	learn: 0.0047280	total: 901ms	remaining: 76.2ms
# 922:	learn: 0.0047226	total: 902ms	remaining: 75.2ms
# 923:	learn: 0.0047159	total: 903ms	remaining: 74.3ms
# 924:	learn: 0.0047086	total: 904ms	remaining: 73.3ms
# 925:	learn: 0.0047039	total: 905ms	remaining: 72.3ms
# 926:	learn: 0.0046988	total: 907ms	remaining: 71.4ms
# 927:	learn: 0.0046913	total: 908ms	remaining: 70.5ms
# 928:	learn: 0.0046871	total: 909ms	remaining: 69.5ms
# 929:	learn: 0.0046823	total: 910ms	remaining: 68.5ms
# 930:	learn: 0.0046770	total: 911ms	remaining: 67.5ms
# 931:	learn: 0.0046731	total: 912ms	remaining: 66.5ms
# 932:	learn: 0.0046673	total: 913ms	remaining: 65.6ms
# 933:	learn: 0.0046620	total: 914ms	remaining: 64.6ms
# 934:	learn: 0.0046568	total: 915ms	remaining: 63.6ms
# 935:	learn: 0.0046510	total: 916ms	remaining: 62.6ms
# 936:	learn: 0.0046471	total: 917ms	remaining: 61.6ms
# 937:	learn: 0.0046424	total: 918ms	remaining: 60.7ms
# 938:	learn: 0.0046360	total: 919ms	remaining: 59.7ms
# 939:	learn: 0.0046294	total: 920ms	remaining: 58.7ms
# 940:	learn: 0.0046232	total: 921ms	remaining: 57.7ms
# 941:	learn: 0.0046199	total: 922ms	remaining: 56.7ms
# 942:	learn: 0.0046146	total: 923ms	remaining: 55.8ms
# 943:	learn: 0.0046075	total: 924ms	remaining: 54.8ms
# 944:	learn: 0.0046017	total: 924ms	remaining: 53.8ms
# 945:	learn: 0.0045964	total: 925ms	remaining: 52.8ms
# 946:	learn: 0.0045915	total: 926ms	remaining: 51.8ms
# 947:	learn: 0.0045862	total: 927ms	remaining: 50.8ms
# 948:	learn: 0.0045817	total: 928ms	remaining: 49.9ms
# 949:	learn: 0.0045754	total: 929ms	remaining: 48.9ms
# 950:	learn: 0.0045698	total: 930ms	remaining: 47.9ms
# 951:	learn: 0.0045658	total: 931ms	remaining: 46.9ms
# 952:	learn: 0.0045612	total: 932ms	remaining: 46ms
# 953:	learn: 0.0045573	total: 933ms	remaining: 45ms
# 954:	learn: 0.0045528	total: 934ms	remaining: 44ms
# 955:	learn: 0.0045457	total: 935ms	remaining: 43ms
# 956:	learn: 0.0045410	total: 936ms	remaining: 42ms
# 957:	learn: 0.0045351	total: 937ms	remaining: 41.1ms
# 958:	learn: 0.0045293	total: 938ms	remaining: 40.1ms
# 959:	learn: 0.0045241	total: 938ms	remaining: 39.1ms
# 960:	learn: 0.0045194	total: 939ms	remaining: 38.1ms
# 961:	learn: 0.0045152	total: 940ms	remaining: 37.1ms
# 962:	learn: 0.0045113	total: 941ms	remaining: 36.1ms
# 963:	learn: 0.0045045	total: 942ms	remaining: 35.2ms
# 964:	learn: 0.0044990	total: 943ms	remaining: 34.2ms
# 965:	learn: 0.0044953	total: 944ms	remaining: 33.2ms
# 966:	learn: 0.0044886	total: 945ms	remaining: 32.2ms
# 967:	learn: 0.0044843	total: 946ms	remaining: 31.3ms
# 968:	learn: 0.0044801	total: 947ms	remaining: 30.3ms
# 969:	learn: 0.0044742	total: 948ms	remaining: 29.3ms
# 970:	learn: 0.0044690	total: 948ms	remaining: 28.3ms
# 971:	learn: 0.0044623	total: 949ms	remaining: 27.3ms
# 972:	learn: 0.0044579	total: 950ms	remaining: 26.4ms
# 973:	learn: 0.0044535	total: 951ms	remaining: 25.4ms
# 974:	learn: 0.0044489	total: 952ms	remaining: 24.4ms
# 975:	learn: 0.0044437	total: 953ms	remaining: 23.4ms
# 976:	learn: 0.0044387	total: 954ms	remaining: 22.4ms
# 977:	learn: 0.0044343	total: 954ms	remaining: 21.5ms
# 978:	learn: 0.0044296	total: 955ms	remaining: 20.5ms
# 979:	learn: 0.0044254	total: 956ms	remaining: 19.5ms
# 980:	learn: 0.0044185	total: 957ms	remaining: 18.5ms
# 981:	learn: 0.0044143	total: 958ms	remaining: 17.6ms
# 982:	learn: 0.0044103	total: 959ms	remaining: 16.6ms
# 983:	learn: 0.0044048	total: 960ms	remaining: 15.6ms
# 984:	learn: 0.0043998	total: 961ms	remaining: 14.6ms
# 985:	learn: 0.0043940	total: 962ms	remaining: 13.7ms
# 986:	learn: 0.0043877	total: 963ms	remaining: 12.7ms
# 987:	learn: 0.0043830	total: 964ms	remaining: 11.7ms
# 988:	learn: 0.0043789	total: 965ms	remaining: 10.7ms
# 989:	learn: 0.0043741	total: 966ms	remaining: 9.75ms
# 990:	learn: 0.0043682	total: 966ms	remaining: 8.78ms
# 991:	learn: 0.0043643	total: 967ms	remaining: 7.8ms
# 992:	learn: 0.0043577	total: 968ms	remaining: 6.82ms
# 993:	learn: 0.0043526	total: 969ms	remaining: 5.85ms
# 994:	learn: 0.0043482	total: 970ms	remaining: 4.87ms
# 995:	learn: 0.0043442	total: 971ms	remaining: 3.9ms
# 996:	learn: 0.0043392	total: 972ms	remaining: 2.92ms
# 997:	learn: 0.0043351	total: 973ms	remaining: 1.95ms
# 998:	learn: 0.0043297	total: 974ms	remaining: 974us
# 999:	learn: 0.0043263	total: 975ms	remaining: 0us
# Accuracy: 0.9333333333333333
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       1.00      0.78      0.88         9
#            2       0.85      1.00      0.92        11
#
#     accuracy                           0.93        30
#    macro avg       0.95      0.93      0.93        30
# weighted avg       0.94      0.93      0.93        30
#
#
# Cross-validation accuracy: 0.97 ± 0.02

# %%
# learning curve berdasarkan training model

from sklearn.model_selection import learning_curve
import numpy as np
import matplotlib.pyplot as plt

# Generate learning curve
train_sizes, train_scores, test_scores = learning_curve(
    model, X_train_scaled, y_train, cv=5, scoring='accuracy', n_jobs=-1, train_sizes=np.linspace(0.1, 1.0, 10)
)

# Calculate mean and standard deviation for training and test scores
train_scores_mean = np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)
test_scores_std = np.std(test_scores, axis=1)

# Plot learning curve
plt.figure(figsize=(10, 6))
plt.fill_between(train_sizes, train_scores_mean - train_scores_std, train_scores_mean + train_scores_std, alpha=0.1, color="r")
plt.fill_between(train_sizes, test_scores_mean - test_scores_std, test_scores_mean + test_scores_std, alpha=0.1, color="g")
plt.plot(train_sizes, train_scores_mean, 'o-', color="r", label="Training score")
plt.plot(train_sizes, test_scores_mean, 'o-', color="g", label="Cross-validation score")

plt.title('Learning Curve')
plt.xlabel('Training examples')
plt.ylabel('Score')
plt.legend(loc="best")
plt.grid()
plt.show()

# %% [markdown]
# #### depth → Ngatur kedalaman decision tree (default: 6). Kalau terlalu dalam, model jadi terlalu kompleks. Kita coba turunin dulu.
# #### learning_rate → Ngatur seberapa besar langkah update model (default: 0.03). Kalau terlalu tinggi, model bisa nggak stabil; kalau terlalu kecil, konvergensinya lambat. Kita coba eksperimen.
# #### l2_leaf_reg → Regularisasi L2 buat leaf node biar nggak terlalu fit ke data (default: 3). Kita coba naikin buat nge-rem overfitting.
# #### iterations → Jumlah boosting rounds. Bisa coba naikin atau turunin sambil lihat performa.

# %%
# Hyperparameter gridsearch

from catboost import CatBoostClassifier
from sklearn.model_selection import GridSearchCV

# Inisialisasi model
cat_model = CatBoostClassifier(verbose=0, early_stopping_rounds=10)

# Hyperparameter grid
param_grid = {
    'depth': [1, 2, 3, 4, 5],  # Turunin dari sebelumnya 6-10
    'learning_rate': [0.01, 0.03, 0.05],
    'l2_leaf_reg': [8, 9, 11, 15],  # Coba naikkan
    'iterations': [40, 45, 50]
}

# GridSearchCV
grid_search = GridSearchCV(cat_model, param_grid, cv=5, scoring='accuracy', n_jobs=-1)
grid_search.fit(X_train_scaled, y_train)

# Hasil terbaik
print(f"Best params: {grid_search.best_params_}")
print(f"Best cross-validation score: {grid_search.best_score_}")

# Evaluasi di test set
best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test_scaled)

from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
# Best params: {'depth': 3, 'iterations': 45, 'l2_leaf_reg': 9, 'learning_rate': 0.03}
# Best cross-validation score: 0.975
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       1.00      0.89      0.94         9
#            2       0.92      1.00      0.96        11
#
#     accuracy                           0.97        30
#    macro avg       0.97      0.96      0.97        30
# weighted avg       0.97      0.97      0.97        30

# %%
# learning curve berdasarkan GridSearchCV

from sklearn.model_selection import learning_curve
import numpy as np
import matplotlib.pyplot as plt

# Generate learning curve
train_sizes, train_scores, test_scores = learning_curve(
    best_model, X_train_scaled, y_train, cv=5, scoring='accuracy', n_jobs=-1, train_sizes=np.linspace(0.1, 1.0, 10)
)

# Calculate mean and standard deviation for training and test scores
train_scores_mean = np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)
test_scores_std = np.std(test_scores, axis=1)

# Plot learning curve
plt.figure(figsize=(10, 6))
plt.fill_between(train_sizes, train_scores_mean - train_scores_std, train_scores_mean + train_scores_std, alpha=0.1, color="r")
plt.fill_between(train_sizes, test_scores_mean - test_scores_std, test_scores_mean + test_scores_std, alpha=0.1, color="g")
plt.plot(train_sizes, train_scores_mean, 'o-', color="r", label="Training score")
plt.plot(train_sizes, test_scores_mean, 'o-', color="g", label="Cross-validation score")

plt.title('Learning Curve')
plt.xlabel('Training examples')
plt.ylabel('Score')
plt.legend(loc="best")
plt.grid()
plt.show()

#Dari grafik learning curve yang terakhir (dengan learning_rate = 0.03), ini nggak overfitting, Cen. Aku jelasin kenapa:
#Training score (garis merah) dan Cross-validation score (garis hijau) mendekati satu sama lain di titik-titik akhir — artinya model performanya konsisten baik di data training maupun validasi.
#Ada gap kecil di awal, tapi makin banyak data training, gap itu makin menutup. Ini tanda kalau model belajar dengan baik dan nggak "terjebak" di data training aja.
#Cross-validation score cukup stabil dan tetap tinggi, jadi model juga bisa generalisasi dengan baik ke data baru.

# %%
# evaluasi total

from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score
import seaborn as sns

import matplotlib.pyplot as plt

# Generate confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=dataset.target_names, yticklabels=dataset.target_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# Calculate precision, recall, and F1 score
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')

print(f'Precision: {precision}')
print(f'Recall: {recall}')
print(f'F1 Score: {f1}')
# Out:
# Precision: 0.9694444444444444
# Recall: 0.9666666666666667
# F1 Score: 0.9664109121909632

# %%
# cross validation

import numpy as np

# Perform 5-fold cross validation
cv_scores = cross_val_score(best_model, X, y, cv=5, scoring='accuracy')

# Print cross-validation results
print("Cross-validation scores:", cv_scores)
print("Average CV score: {:.3f} (+/- {:.3f})".format(cv_scores.mean(), cv_scores.std() * 2))
# Out:
# Cross-validation scores: [0.96666667 0.96551724 0.93103448 0.89655172 1.        ]
# Average CV score: 0.952 (+/- 0.071)
